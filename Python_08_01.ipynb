# %%
#basic use of print function
print("Hello World")
# Out:
# Hello World

# %%
x='Hello world'
print(x)
# Out:
# Hello world

# %%
print(2+10)
print(100.5)
print(10-2)
print(10*10)
print(10/10)
# Out:
# 12
# 100.5
# 8
# 100
# 1.0

# %%
print(2,4,6,8,10, sep='\n')
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
a=2
b=3
sum=a+b
print(sum)
# Out:
# 5
